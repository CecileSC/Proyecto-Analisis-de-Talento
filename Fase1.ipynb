# %% [markdown]
# ¿Cómo interpretar los negativos en la columna DistanceFromHome? Puede haber empleados de on site en otras empresas haciendo labor de consultoría.
# ¿La Distancia está en km?
# ¿Qué es Monthlyrate?

# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv("HR RAW DATA.csv")
df.tail()
# Out:
#       Unnamed: 0 Age Attrition BusinessTravel DailyRate Department  \
# 1609        1609  36       Yes  travel_rarely    530,0$        NaN
# 1610        1610  45        No     non-travel    805,0$        NaN
# 1611        1611  39        No  travel_rarely    903,0$        NaN
# 1612        1612  36        No     non-travel   1229,0$        NaN
# 1613        1613  46        No            NaN    566,0$        NaN
#
#       DistanceFromHome  Education    EducationField  employeecount  \
# 1609                 3          1     Life Sciences              1
# 1610                 4          2               NaN              1
# 1611               -13          5               NaN              1
# 1612                 8          4  Technical Degree              1
# 1613                 7          2           Medical              1
#
#      employeenumber  EnvironmentSatisfaction  Gender HourlyRate  \
# 1609          967,0                        3       0         51
# ...

# %%
df[df["DistanceFromHome"]<0]["DistanceFromHome"].min()
# Out:
# -49

# %%
df[df["DistanceFromHome"]>0]["DistanceFromHome"].max()
# Out:
# 29

# %%
len(df["YearsInCurrentRole"].dropna())
# Out:
# 34

# %%
pd.set_option('display.max_columns', None)

# %%
df["SameAsMonthlyIncome"].describe()
# Out:
# count        771
# unique       668
# top       6347,0
# freq           4
# Name: SameAsMonthlyIncome, dtype: object

# %%
df["MonthlyIncome"].describe()
# Out:
# count        771
# unique       668
# top       6347,0
# freq           4
# Name: MonthlyIncome, dtype: object

# %%
df.loc[:,["DailyRate", "HourlyRate", "MonthlyIncome", "MonthlyRate", "PercentSalaryHike", "StandardHours"]]
# Out:
#      DailyRate HourlyRate MonthlyIncome  MonthlyRate  PercentSalaryHike  \
# 0       684,0$         51       19537,0         6462                 13
# 1       699,0$         65       19999,0         5678                 14
# 2       532,0$         58       19232,0         4933                 11
# 3       359,0$         82       17169,0        26703                 19
# 4      1319,0$         45           NaN         7739                 12
# ...        ...        ...           ...          ...                ...
# 1609    530,0$         51       10325,0         5518                 11
# 1610    805,0$         57        4447,0        23163                 12
# 1611    903,0$         41           NaN         2560                 18
# 1612   1229,0$         84           NaN        25952                 13
# 1613    566,0$         75       10845,0        24208                 13
#
#      StandardHours
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# ...

# %% [markdown]
# ### Tareas realizadas:
# Eliminar columna:
#     - Salary - Todos los valores tienen el mismo dato (1000000000$) - Ok en df_limpio
#     - SameAsMonthlyIncome - Hemos comprobado que los datos son los mismos que la columna MonthlyIncome - Ok en df_limpio
#     - employeecount - Todos los valores son 1 - Ok en df_limpio
#     - NUMBERCHILDREN - Todos los valores son nulos. Ok en df_limpio

# %% [markdown]
# ### Tareas pendientes:
#
# 1. Cambiar datos:
#
#     1.1. Distancia al trabajo - Cambiar los negativos por positivos (confirmado por negocio)
#
#     1.2. RemoteWork - (Unificar datos 0 y false) - (Yes, True y 1)
#
#     1.3. RoleDepartament - Renombrar.
#
#     1.4. Age - Pasarlo a integer.
#
# 2. Dudas:
#
#     2.1. StandardHours - Todos los valores no nulos son valor unico 80 , 419 registros.Confirmar si los valores nulos corresponden  a jornada completa y los otros a media jornada
#
#     2.2. BusinessTravel - Como interpretamos los nulos?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1614 entries, 0 to 1613
# Data columns (total 42 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                1614 non-null   int64
#  1   Age                       1614 non-null   object
#  2   Attrition                 1614 non-null   object
#  3   BusinessTravel            842 non-null    object
#  4   DailyRate                 1614 non-null   object
#  5   Department                302 non-null    object
#  6   DistanceFromHome          1614 non-null   int64
#  7   Education                 1614 non-null   int64
#  8   EducationField            869 non-null    object
#  9   employeecount             1614 non-null   int64
#  10  employeenumber            1183 non-null   object
#  11  EnvironmentSatisfaction   1614 non-null   int64
#  12  Gender                    1614 non-null   int64
# ...

# %%
df["Over18"].isnull().sum()
# Out:
# 901

# %%
df["Over18"].value_counts()
# Out:
# Over18
# Y    713
# Name: count, dtype: int64

# %%
df_limpio.drop(labels="SameAsMonthlyIncome", axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 df_limpio.drop(labels="SameAsMonthlyIncome", axis=1, inplace=True)
#
# NameError: name 'df_limpio' is not defined

# %%
df["DistanceFromHome"].isna().sum()
# Out:
# 0

# %%
df["DistanceFromHome"].value_counts()
# Out:
# DistanceFromHome
#  2     217
#  1     203
#  10     86
#  9      85
#  8      81
#       ...
# -28      2
# -34      2
# -43      2
# -39      1
# -40      1
# Name: count, Length: 69, dtype: int64

# %%
df.iloc[:,5:]
# Out:
#                     Department  DistanceFromHome  Education    EducationField  \
# 0                          NaN                 6          3               NaN
# 1                          NaN                 1          4     Life Sciences
# 2      Research & Development                  4          2  Technical Degree
# 3                          NaN                 2          4           Medical
# 4                          NaN                 3          3  Technical Degree
# ...                        ...               ...        ...               ...
# 1609                       NaN                 3          1     Life Sciences
# 1610                       NaN                 4          2               NaN
# 1611                       NaN               -13          5               NaN
# 1612                       NaN                 8          4  Technical Degree
# 1613                       NaN                 7          2           Medical
#
# ...

# %%
df.describe(include="O").T
# Out:
#                     count unique                       top  freq
# Age                  1614     54                        35    84
# Attrition            1614      2                        No  1355
# BusinessTravel        842      3             travel_rarely   586
# DailyRate            1614    849                      nan$   124
# Department            302      3   Research & Development    196
# EducationField        869      6             Life Sciences   349
# employeenumber       1183   1079                     482,0     2
# HourlyRate           1614     72             Not Available    84
# JobRole              1614   1579                  mANager      4
# MaritalStatus         963      5                   Married   404
# MonthlyIncome         771    668                    6347,0     4
# Over18                713      1                         Y   713
# OverTime              938      2                        No   682
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Age', 'Attrition', 'BusinessTravel', 'DailyRate',
#        'Department', 'DistanceFromHome', 'Education', 'EducationField',
#        'employeecount', 'employeenumber', 'EnvironmentSatisfaction', 'Gender',
#        'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole',
#        'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate',
#        'NUMCOMPANIESWORKED', 'Over18', 'OverTime', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours',
#        'StockOptionLevel', 'TOTALWORKINGYEARS', 'TrainingTimesLastYear',
#        'WORKLIFEBALANCE', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YEARSWITHCURRMANAGER',
#        'SameAsMonthlyIncome', 'DateBirth', 'Salary', 'RoleDepartament',
#        'NUMBERCHILDREN', 'RemoteWork'],
#       dtype='object')

# %%
eliminar = ['employeecount','Over18','SameAsMonthlyIncome','Salary']
df_limpio = df.drop(columns=eliminar)

# %%
df_limpio
# Out:
#       Unnamed: 0 Age Attrition BusinessTravel DailyRate  \
# 0              0  51        No            NaN    684,0$
# 1              1  52        No            NaN    699,0$
# 2              2  42        No  travel_rarely    532,0$
# 3              3  47        No  travel_rarely    359,0$
# 4              4  46        No            NaN   1319,0$
# ...          ...  ..       ...            ...       ...
# 1609        1609  36       Yes  travel_rarely    530,0$
# 1610        1610  45        No     non-travel    805,0$
# 1611        1611  39        No  travel_rarely    903,0$
# 1612        1612  36        No     non-travel   1229,0$
# 1613        1613  46        No            NaN    566,0$
#
#                     Department  DistanceFromHome  Education    EducationField  \
# 0                          NaN                 6          3               NaN
# 1                          NaN                 1          4     Life Sciences
# ...

# %%
cambiar_nombre = {"employeenumber": "EmployerNumber", "NUMCOMPANIESWORKED": "NumCompaniesWorked", "TOTALWORKINGYEARS": "TotalWorkingYeras", "WORKLIFEBALANCE": "WorkLifeBalance",
                  "YEARSWITHCURRMANAGER": "YearsWithCurrManager", "NUMBERCHILDREN": "NumberChildren"}

df_limpio.rename(columns=cambiar_nombre, inplace=True)
df_limpio
# Out:
#       Unnamed: 0 Age Attrition BusinessTravel DailyRate  \
# 0              0  51        No            NaN    684,0$
# 1              1  52        No            NaN    699,0$
# 2              2  42        No  travel_rarely    532,0$
# 3              3  47        No  travel_rarely    359,0$
# 4              4  46        No            NaN   1319,0$
# ...          ...  ..       ...            ...       ...
# 1609        1609  36       Yes  travel_rarely    530,0$
# 1610        1610  45        No     non-travel    805,0$
# 1611        1611  39        No  travel_rarely    903,0$
# 1612        1612  36        No     non-travel   1229,0$
# 1613        1613  46        No            NaN    566,0$
#
#                     Department  DistanceFromHome  Education    EducationField  \
# 0                          NaN                 6          3               NaN
# 1                          NaN                 1          4     Life Sciences
# ...

# %%
df_limpio["JobRole"] = df_limpio["JobRole"].str.title()
df_limpio
# Out:
#       Unnamed: 0 Age Attrition BusinessTravel DailyRate  \
# 0              0  51        No            NaN    684,0$
# 1              1  52        No            NaN    699,0$
# 2              2  42        No  travel_rarely    532,0$
# 3              3  47        No  travel_rarely    359,0$
# 4              4  46        No            NaN   1319,0$
# ...          ...  ..       ...            ...       ...
# 1609        1609  36       Yes  travel_rarely    530,0$
# 1610        1610  45        No     non-travel    805,0$
# 1611        1611  39        No  travel_rarely    903,0$
# 1612        1612  36        No     non-travel   1229,0$
# 1613        1613  46        No            NaN    566,0$
#
#                     Department  DistanceFromHome  Education    EducationField  \
# 0                          NaN                 6          3               NaN
# 1                          NaN                 1          4     Life Sciences
# ...

# %%
df_limpio["MaritalStatus"].value_counts()
# Out:
# MaritalStatus
# Married     439
# Single      325
# Divorced    199
# Name: count, dtype: int64

# %%
df_limpio["MaritalStatus"] = df_limpio["MaritalStatus"].str.title()

df_limpio["MaritalStatus"] = df_limpio["MaritalStatus"].str.replace("Marreid", "Married")

# %%
df_limpio["DistanceFromHome"] = df_limpio["DistanceFromHome"].abs()
df_limpio
# Out:
#       Unnamed: 0 Age Attrition BusinessTravel DailyRate  \
# 0              0  51        No            NaN    684,0$
# 1              1  52        No            NaN    699,0$
# 2              2  42        No  travel_rarely    532,0$
# 3              3  47        No  travel_rarely    359,0$
# 4              4  46        No            NaN   1319,0$
# ...          ...  ..       ...            ...       ...
# 1609        1609  36       Yes  travel_rarely    530,0$
# 1610        1610  45        No     non-travel    805,0$
# 1611        1611  39        No  travel_rarely    903,0$
# 1612        1612  36        No     non-travel   1229,0$
# 1613        1613  46        No            NaN    566,0$
#
#                     Department  DistanceFromHome  Education    EducationField  \
# 0                          NaN                 6          3               NaN
# 1                          NaN                 1          4     Life Sciences
# ...

# %%
df_limpio["EnvironmentSatisfaction"].value_counts()
# Out:
# EnvironmentSatisfaction
# 4     460
# 3     459
# 1     298
# 2     297
# 12      7
# 35      6
# 13      6
# 14      5
# 24      5
# 47      5
# 36      4
# 48      4
# 41      4
# 46      4
# 42      4
# 45      3
# 11      3
# 22      3
# 17      3
# 18      3
# 20      3
# 25      3
# 27      3
# 37      2
# 29      2
# 19      2
# 38      2
# 31      2
# 15      2
# 16      2
# 26      1
# 39      1
# 10      1
# 49      1
# 21      1
# 28      1
# 33      1
# 43      1
# Name: count, dtype: int64

# %%
df_limpio['EnvironmentSatisfaction'] = df_limpio["EnvironmentSatisfaction"].astype(str)

# %%
df_limpio['EnvironmentSatisfaction'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        1
# 1        3
# 2        3
# 3        1
# 4        1
#         ..
# 1609     3
# 1610     3
# 1611    13
# 1612     1
# 1613     4
# Name: EnvironmentSatisfaction, Length: 1614, dtype: object>

# %%
#SOLUCIONAR ESTO

df_limpio['EnvironmentSatisfaction'].str.split(expand=True).get([0])
# Out:
#        0
# 0      1
# 1      3
# 2      3
# 3      1
# 4      1
# ...   ..
# 1609   3
# 1610   3
# 1611  13
# 1612   1
# 1613   4
#
# [1614 rows x 1 columns]

# %%
numero = 5
primer_digito = df_limpio["EnvironmentSatisfaction"].str(df_limpio["EnvironmentSatisfaction"][0])
print(primer_digito)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[65], line 2
#       1 numero = 5
# ----> 2 primer_digito = df_limpio["EnvironmentSatisfaction"].str(df_limpio["EnvironmentSatisfaction"][0])
#       3 print(primer_digito)
#
# TypeError: 'StringMethods' object is not callable

# %%
resultados = []
for texto in df['texto']: primer_digito = df_limpio['EnvironmentSatisfaction'][0] 
df['primeros_digitos'] = resultados 
print(df)

# %%
df_limpio["RemoteWork"] = df_limpio["RemoteWork"].str.replace("1", "True").replace("0", "False").replace("Yes", "True")
df_limpio
# Out:
#       Unnamed: 0 Age Attrition BusinessTravel DailyRate  \
# 0              0  51        No            NaN    684,0$
# 1              1  52        No            NaN    699,0$
# 2              2  42        No  travel_rarely    532,0$
# 3              3  47        No  travel_rarely    359,0$
# 4              4  46        No            NaN   1319,0$
# ...          ...  ..       ...            ...       ...
# 1609        1609  36       Yes  travel_rarely    530,0$
# 1610        1610  45        No     non-travel    805,0$
# 1611        1611  39        No  travel_rarely    903,0$
# 1612        1612  36        No     non-travel   1229,0$
# 1613        1613  46        No            NaN    566,0$
#
#                     Department  DistanceFromHome  Education    EducationField  \
# 0                          NaN                 6          3               NaN
# 1                          NaN                 1          4     Life Sciences
# ...

# %%
df_limpio["NumberChildren"].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
df_limpio = df_limpio.drop(columns="NumberChildren")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 df_limpio = df_limpio.drop(columns="NumberChildren")
#       2 df_limpio
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
# ...

# %%
df_limpio
# Out:
#       Unnamed: 0 Age Attrition BusinessTravel DailyRate  \
# 0              0  51        No            NaN    684,0$
# 1              1  52        No            NaN    699,0$
# 2              2  42        No  travel_rarely    532,0$
# 3              3  47        No  travel_rarely    359,0$
# 4              4  46        No            NaN   1319,0$
# ...          ...  ..       ...            ...       ...
# 1609        1609  36       Yes  travel_rarely    530,0$
# 1610        1610  45        No     non-travel    805,0$
# 1611        1611  39        No  travel_rarely    903,0$
# 1612        1612  36        No     non-travel   1229,0$
# 1613        1613  46        No            NaN    566,0$
#
#                     Department  DistanceFromHome  Education    EducationField  \
# 0                          NaN                 6          3               NaN
# 1                          NaN                 1          4     Life Sciences
# ...
