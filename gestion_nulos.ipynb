# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning) # elimina los errres de que van a cambiar

# importamos las librerías que necesitamos
# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np

# Imputación de nulos usando métodos avanzados estadísticos
# -----------------------------------------------------------------------
from sklearn.impute import SimpleImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.impute import KNNImputer

# Librerías de visualización
# -----------------------------------------------------------------------
import seaborn as sns
import matplotlib.pyplot as plt
# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# %%
df = pd.read_csv("hr_raw_data_limpio_.csv", index_col=0)

# %%
df.head()
# Out:
#    Age Attrition BusinessTravel  DailyRate                Department  \
# 0   51        No            NaN      684.0                       NaN
# 1   52        No            NaN      699.0                       NaN
# 2   42        No  Travel Rarely      532.0   Research & Development
# 3   47        No  Travel Rarely      359.0                       NaN
# 4   46        No            NaN     1319.0                       NaN
#
#    DistanceFromHome    Education    EducationField  EmployeeNumber  \
# 0                 6  High School               NaN           162.0
# 1                 1   Bachelor'S     Life Sciences           259.0
# 2                 4    Secondary  Technical Degree           319.0
# 3                 2   Bachelor'S           Medical             NaN
# 4                 3  High School  Technical Degree             NaN
#
#   EnvironmentSatisfaction  Gender  HourlyRate JobInvolvement  JobLevel  \
# 0                Very Low    Male        51.0         Medium  Director
# 1                  Medium    Male        65.0            Low  Director
# 2                  Medium    Male        58.0         Medium  Director
# 3                Very Low  Female        82.0         Medium   Manager
# 4                Very Low  Female        45.0           High   Manager
#
#                JobRole JobSatisfaction MaritalStatus  MonthlyIncome  \
# 0   Research Director           Medium           NaN        19537.0
# 1             Manager           Medium           NaN        19999.0
# 2             Manager             High       Married        19232.0
# 3   Research Director           Medium       Married        17169.0
# 4     Sales Executive         Very Low      Divorced            NaN
#
#    MonthlyRate  NumCompaniesWorked OverTime  PercentSalaryHike  \
# 0         6462                   7       No                 13
# 1         5678                   0      NaN                 14
# 2         4933                   1       No                 11
# 3        26703                   3      NaN                 19
# 4         7739                   2       No                 12
#
#   PerformanceRating RelationshipSatisfaction  StandardHours StockOptionLevel  \
# 0               3,0                   Medium            NaN              NaN
# 1               3,0                 Very Low            NaN              Low
# 2               3,0                     High            NaN              NaN
# 3               3,0                      Low            NaN           Medium
# 4               3,0                     High            NaN              Low
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                NaN                      5             3,0              20
# 1               34.0                      5             3,0              33
# 2               22.0                      3             NaN              22
# 3                NaN                      2             NaN              20
# 4                NaN                      5             3,0              19
#
#    YearsSinceLastPromotion  YearsWithCurrManager  \
# 0                       15                    15
# 1                       11                     9
# 2                       11                    15
# 3                        5                     6
# 4                        2                     8
#
#                         RoleDepartament RemoteWork
# 0                                   NaN        Yes
# 1                                   NaN        Yes
# 2   Manager     Research & Development         Yes
# 3                                   NaN         No
# 4                                   NaN         No

# %%
df["BusinessTravel"].value_counts()
# Out:
# BusinessTravel
# Travel Rarely        586
# Travel Frequently    165
# Non Travel            91
# Name: count, dtype: int64

# %%
df["BusinessTravel"].isna().sum()
# Out:
# 772

# %%
df[["BusinessTravel","EnvironmentSatisfaction"]]
# Out:
#      BusinessTravel EnvironmentSatisfaction
# 0               NaN                Very Low
# 1               NaN                  Medium
# 2     Travel Rarely                  Medium
# 3     Travel Rarely                Very Low
# 4               NaN                Very Low
# ...             ...                     ...
# 1609  Travel Rarely                  Medium
# 1610     Non Travel                  Medium
# 1611  Travel Rarely                Very Low
# 1612     Non Travel                Very Low
# 1613            NaN                    High
#
# [1614 rows x 2 columns]
